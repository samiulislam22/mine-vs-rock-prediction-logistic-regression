# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
sonar_data = pd.read_csv("sonar_data.csv" , header = None)
sonar_data.head(10)
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 5  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 6  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 7  0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 8  0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 9  0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# ...

# %%
sonar_data.shape
sonar_data.describe()  # gives statistical measures of the data
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar_data[60].value_counts()  # gives the number of values for each label R or M
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
sonar_data.groupby(60).mean()  # gives the mean of each column for each label R and M
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
# separating data and labels
X = sonar_data.drop(60, axis =1)  # Drop column 60 axis=1 means drop column and axis=0 means drop row
Y = sonar_data[60]
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
# test_size = 0.1 means 10% data will be test data and 90% data will be train data

# stratify = Y means data will be split in such a way that the proportion of labels(Rock and Mine) in train and test data will be same as in original data

X_Train, X_Test , Y_Train, Y_Test = train_test_split(X,Y , test_size = 0.1 , stratify = Y , random_state = 1)

# %%
print(X.shape , X_Train.shape,X_Test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %%
# Model Training
model = LogisticRegression()
model.fit(X_Train,Y_Train)
# Out:
# LogisticRegression()

# %%
#finding the accuracy of the model on train data
X_Train_Prediction = model.predict(X_Train)
training_data_accuracy = accuracy_score(X_Train_Prediction , Y_Train)
print(f"Accuracy on Training data : {training_data_accuracy*100:.2f}%")
# Out:
# Accuracy on Training data : 83.42%

# %%
# finding the accuracy of the model on test data
X_Test_Prediction = model.predict(X_Test)
test_data_accuracy = accuracy_score(X_Test_Prediction , Y_Test)
print(f"Accuracy on Test data : {test_data_accuracy*100:.2f}%")
# Out:
# Accuracy on Test data : 76.19%

# %%
#Creating a Predicting System
input_data = (
    0.2280, 0.0445, 0.1006, 0.1919, 0.2354,
    0.2744, 0.3658, 0.5331, 0.6183, 0.7954,
    0.8613, 0.7061, 0.5478, 0.3042, 0.2436,
    0.3771, 0.5598, 0.6194, 0.6333, 0.7060,
    0.5544, 0.5320, 0.6479, 0.6931, 0.6759,
    0.7551, 0.8929, 0.8619, 0.7974, 0.6737,
    0.4293, 0.3648, 0.5331, 0.2413, 0.5070,
    0.8533, 0.6036, 0.8514, 0.8512, 0.5045,
    0.1862, 0.2709, 0.4232, 0.3043, 0.6116,
    0.6756, 0.5375, 0.4719, 0.4647, 0.2587,
    0.2129, 0.2222, 0.2111, 0.0176, 0.1348,
    0.0744, 0.0130, 0.0106, 0.0033, 0.0232
)
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1) # (1,-1) means we are predicting for one instance and -1 means the number of columns will be automatically determined

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 'R'):
    print("The object is a Rock")
else:
    print("The object is a Mine")
# Out:
# ['M']
# The object is a Mine
